# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(14,5), dpi=320, facecolor='w', edgecolor='k')
plt.title(f"Loss by depth")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid()
for n_layers in range(1,9):
    history = pd.read_csv(f"analysis/loss-df-main-{n_layers}.csv")
    plt.plot(history['Loss'], label=f"Loss depth {n_layers}")
    plt.xticks(range(0, len(history['Loss'])+1, 5))
    plt.legend(loc='best')
    #plt.plot(history['Val Loss'], label="Val Loss/Epoch")

# %%
plt.figure(figsize=(14,5), dpi=320, facecolor='w', edgecolor='k')
plt.title(f"Val Loss by depth")
plt.xlabel("Epoch")
plt.ylabel("Val Loss")
plt.grid()
for n_layers in range(1,9):
    history = pd.read_csv(f"analysis/loss-df-main-{n_layers}.csv")
    plt.plot(history['Val Loss'], label=f"Val Loss depth {n_layers}")
    plt.xticks(range(0, len(history['Val Loss'])+1, 5))
    plt.legend(loc='best')

# %%
df = pd.read_csv("analysis/metrics-main-train150_mucuri.txt")
df
# Out:
#      Index       MAE       MSE      NMSE      RMSE     NRMSE         R  \
# 0  1 depth  1.054650  1.684737  0.230383  1.297974  0.479982  0.890470
# 1  2 depth  0.836950  1.151504  0.157465  1.073082  0.396818  0.922096
# 2  3 depth  1.693133  4.637121  0.634113  2.153398  0.796312  0.802256
# 3  4 depth  0.979715  1.480788  0.202493  1.216876  0.449993  0.921191
# 4  5 depth  1.272660  2.677337  0.366118  1.636257  0.605077  0.887264
# 5  6 depth  0.855437  1.119894  0.153142  1.058250  0.391334  0.920447
# 6  7 depth  0.874501  1.188340  0.162502  1.090110  0.403115  0.921274
# 7  8 depth  0.842199  1.145847  0.156691  1.070442  0.395842  0.921982
# 8    Média  1.051155  1.885696  0.257863  1.324549  0.489809  0.898373
#
#          R²  Fator de 2
# 0  0.768417    1.000000
# 1  0.841715    1.000000
# 2  0.362584    0.979275
# 3  0.796452    1.000000
# 4  0.631975    1.000000
# 5  0.846060    1.000000
# 6  0.836652    1.000000
# 7  0.842493    1.000000
# 8  0.740793    0.997409

# %%
plt.figure(figsize=(14,5), dpi=320, facecolor='w', edgecolor='k')
plt.title(f"Loss by depth")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid()
for n_layers in range(1,9):
    history = pd.read_csv(f"analysis/loss-df-strong-{n_layers}.csv")
    plt.plot(history['Loss'], label=f"Loss depth {n_layers}")
    plt.xticks(range(0, len(history['Loss'])+1, 5))
    plt.legend(loc='best')
    #plt.plot(history['Val Loss'], label="Val Loss/Epoch")

# %%
plt.figure(figsize=(14,5), dpi=320, facecolor='w', edgecolor='k')
plt.title(f"Val Loss by depth")
plt.xlabel("Epoch")
plt.ylabel("Val Loss")
plt.grid()
for n_layers in range(1,9):
    history = pd.read_csv(f"analysis/loss-df-strong-{n_layers}.csv")
    plt.plot(history['Val Loss'], label=f"Val Loss depth {n_layers}")
    plt.xticks(range(0, len(history['Val Loss'])+1, 5))
    plt.legend(loc='best')

# %%
df = pd.read_csv("analysis/metrics-strong-train150_mucuri.txt")
df
# Out:
#      Index       MAE       MSE      NMSE      RMSE     NRMSE         R  \
# 0  1 depth  1.054650  1.684737  0.230383  1.297974  0.479982  0.890470
# 1  2 depth  0.836950  1.151504  0.157465  1.073082  0.396818  0.922096
# 2  3 depth  1.693133  4.637121  0.634113  2.153398  0.796312  0.802256
# 3  4 depth  0.979715  1.480788  0.202493  1.216876  0.449993  0.921191
# 4  5 depth  1.272660  2.677337  0.366118  1.636257  0.605077  0.887264
# 5  6 depth  0.855437  1.119894  0.153142  1.058250  0.391334  0.920447
# 6  7 depth  0.874501  1.188340  0.162502  1.090110  0.403115  0.921274
# 7  8 depth  0.842199  1.145847  0.156691  1.070442  0.395842  0.921982
# 8    Média  1.051155  1.885696  0.257863  1.324549  0.489809  0.898373
#
#          R²  Fator de 2
# 0  0.768417    1.000000
# 1  0.841715    1.000000
# 2  0.362584    0.979275
# 3  0.796452    1.000000
# 4  0.631975    1.000000
# 5  0.846060    1.000000
# 6  0.836652    1.000000
# 7  0.842493    1.000000
# 8  0.740793    0.997409
