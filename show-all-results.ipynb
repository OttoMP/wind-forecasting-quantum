# %%
import pandas as pd

# %%
df = pd.read_csv("analysis/metrics-train150_mucuri.txt")
df
# Out:
#      Index       MAE        MSE        NMSE      RMSE      NRMSE         R  \
# 0  1 depth  8.945095  83.021749  446.676483  9.111627  21.134722  0.888975
# 1  2 depth  8.711698  81.001463  435.806872  9.000081  20.875988  0.907733
# 2  3 depth  7.271512  55.471982  298.452277  7.447952  17.275771  0.863953
# 3  4 depth  8.226620  71.372338  383.999920  8.448215  19.595916  0.924290
# 4  5 depth  7.860167  65.337370  351.530378  8.083153  18.749143  0.893364
# 5  6 depth  8.644387  78.203782  420.754690  8.843290  20.512306  0.911989
# 6  7 depth  8.408759  74.560248  401.151620  8.634828  20.028770  0.913558
# 7  8 depth  8.767941  81.684735  439.483033  9.037961  20.963851  0.925529
# 8    Média  8.354523  73.831708  397.231909  8.575888  19.892058  0.903674
#
#            R²  Fator de 2
# 0 -448.027412         0.0
# 1 -437.100592         0.0
# 2 -299.023078         0.0
# 3 -385.020972         0.0
# 4 -352.380538         0.0
# 5 -421.969189         0.0
# 6 -402.262945         0.0
# 7 -440.796102         0.0
# 8 -398.322603         0.0

# %% [markdown]
# <img src="plots/loss-history-1.svg"/>
# <img src="plots/loss-history-2.svg"/>
# <img src="plots/loss-history-3.svg"/>
# <img src="plots/loss-history-4.svg"/>
# <img src="plots/loss-history-5.svg"/>
# <img src="plots/loss-history-6.svg"/>
# <img src="plots/loss-history-7.svg"/>
# <img src="plots/loss-history-8.svg"/>

# %% [markdown]
# <img src="plots/predction-1.svg"/>
# <img src="plots/predction-2.svg"/>
# <img src="plots/predction-3.svg"/>
# <img src="plots/predction-4.svg"/>
# <img src="plots/predction-5.svg"/>
# <img src="plots/predction-6.svg"/>
# <img src="plots/predction-7.svg"/>
# <img src="plots/predction-8.svg"/>
