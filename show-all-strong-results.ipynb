# %%
import pandas as pd

# %%
df = pd.read_csv("analysis/metrics-strong-train150_mucuri.txt")
df
# Out:
#      Index       MAE       MSE      NMSE      RMSE     NRMSE         R  \
# 0  1 depth  2.235416  7.066364  0.995401  2.658263  0.997698  0.296976
# 1  2 depth  0.884270  1.219079  0.171725  1.104119  0.414397  0.919100
# 2  3 depth  0.833427  1.122990  0.158190  1.059712  0.397730  0.918713
# 3  4 depth  0.842055  1.120907  0.157896  1.058729  0.397362  0.917291
# 4  5 depth  0.890771  1.157379  0.163034  1.075816  0.403774  0.920905
# 5  6 depth  0.913452  1.227584  0.172923  1.107964  0.415840  0.916196
# 6  7 depth  0.864237  1.173219  0.165265  1.083152  0.406528  0.913880
# 7  8 depth  0.900030  1.168951  0.164664  1.081180  0.405788  0.919489
# 8    Média  1.045457  1.907059  0.268637  1.278617  0.479890  0.840319
#
#          R²  Fator de 2
# 0 -0.000640    0.994764
# 1  0.827371    1.000000
# 2  0.840978    1.000000
# 3  0.841273    1.000000
# 4  0.836108    1.000000
# 5  0.826167    1.000000
# 6  0.833865    1.000000
# 7  0.834470    1.000000
# 8  0.729949    0.999346

# %% [markdown]
# <img src="plots/loss-history-strong-1.svg"/>
# <img src="plots/loss-history-strong-2.svg"/>
# <img src="plots/loss-history-strong-3.svg"/>
# <img src="plots/loss-history-strong-4.svg"/>
# <img src="plots/loss-history-strong-5.svg"/>
# <img src="plots/loss-history-strong-6.svg"/>
# <img src="plots/loss-history-strong-7.svg"/>
# <img src="plots/loss-history-strong-8.svg"/>

# %% [markdown]
# <img src="plots/prediction-strong-1.svg"/>
# <img src="plots/prediction-strong-2.svg"/>
# <img src="plots/prediction-strong-3.svg"/>
# <img src="plots/prediction-strong-4.svg"/>
# <img src="plots/prediction-strong-5.svg"/>
# <img src="plots/prediction-strong-6.svg"/>
# <img src="plots/prediction-strong-7.svg"/>
# <img src="plots/prediction-strong-8.svg"/>
